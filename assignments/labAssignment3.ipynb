# %% [markdown]
# <a href="https://colab.research.google.com/github/KhasonFacey/Music-Computing-/blob/main/assignments/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# Cloning into 'musicComputing2026'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 120 (delta 53), reused 10 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 14.08 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
def plotAudio2(sig,sampleRate,title):



   # this version expects the audio file to have already been opened by librosa


   # Adjust the x-axis to represent time


   time=np.arange(0,sig.shape[0])/sampleRate


   # Scale the y-axis to represent amplitude from -1 to 1
   excursion=max(abs(sig))
   sigNew = sig / excursion


   # Label the x and y axes with variables
   xlabel = 'Time (seconds)'
   ylabel = 'Amplitude'


   #plot the signal using the x and y axis variables
   plt.plot(time,sigNew)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   plt.title(title)
   plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    # then make all of values in the spectrogram positive with np.abs()
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()

    # display the normalized spectrogram with a log frequency scale
      spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):

    #call plotAudio2
     plotAudio2(sig,sr,title)



    #call plotAudioFreqDomain
     plotAudioFreqDomain(sig,sr,title,winSize,specType)

# %%
sig, sr = librosa.load('musicComputing2026/audioFiles/avm.wav')
IPython.display.Audio(sig, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'

#call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)

spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)
librosa.display.specshow(spec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.show()

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'

#call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)
spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)
librosa.display.specshow(spec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.show()

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'

#call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)

spec2 = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=256)), ref=np.max)
librosa.display.specshow(spec2, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.show()

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'

# call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)

spec2 = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=256)), ref=np.max)
librosa.display.specshow(spec2, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
plt.show()
